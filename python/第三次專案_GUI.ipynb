# %%
import tkinter as tk
from tkinter import *
import tkinter.ttk as ttk
from tkcalendar import Calendar
from tkinterhtml import HtmlFrame
import webbrowser
from tkinter import messagebox
import pymongo
import pandas as pd

client=pymongo.MongoClient("mongodb+srv://s972192006:leeyuet841120@cluster0.jcgpz.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# def search():
#     result=collection.find({"District":dist})
    
#     for item in result:
#         if item["Car_Park_State"]=="No":
#             if int(item["Price"])<2500:
#                 if int(item["Price"])<1400:
#                     print(item["Name"])
#                     lb3.config(text=item["Name"])
#                     lb4.config(text=item["Roomtype"])
#                     lb5.config(text=item["Price"])


#取所有條件的值      
def choose():
    date_choose=cal.selection_get()
    print(date_choose)
    
    city=place_r.get()
    if city=="台北市":
        db_collection="Taipei"
    elif city=="新北市":
        db_collection="New_Taipei"
    elif city=="桃園市":
        db_collection="Taoyuan"
    elif city=="台中市":
        db_collection="Taichung"
    elif city=="台南市":
        db_collection="Tainan"
    elif city=="高雄市":
        db_collection="Kaohsiung"        
    
    people_num=people_r.get()
    if people_num=="2人":
        db_name="Two_p"
    elif people_num=="4人":
        db_name="Four_p"
    
    factor=rates_r.get()
    
    car_p=v.get()
    
    price_low=dollar_low.get()
    print(price_low)
    
    price_hight=dollar_hight.get()
    
    return date_choose,city,db_collection,db_name,people_num,factor,car_p,price_low,price_hight
              
#get 選擇日期       
def grad_date():
    day.config(text=cal.selection_get())

#連到google map
def map_browser():
    webbrowser.open(item["Map_link"])

#連到booking
def booking_browser():
    webbrowser.open(item["Link"])

#提醒-條件缺少
def error():
    messagebox.showinfo("錯誤","條件不全，請重新確認")

#搜尋中請稍後
def wait_s():
    lb1.config(bg="#FFFFFF",fg="#1C1C1C",font=('微軟正黑體',13),text="搜尋中，請稍後")

    
def c_title():

    date_choose,city,db_collection,db_name,people_num,factor,car_p,price_low,price_hight=choose()

    if date_choose==None or city =="地區" or people_num=="住宿人數" or factor=="選項" or car_p==None or int(price_low)<1 or int(price_hight)< int(price_low) :
        error()
    else:
        wait_s()
#         lb1.destroy()
#         canvas.delete(reslut_bg) #刪除遮擋畫布
        
        #用人數選資料庫
        db = client[db_name]
        
        
        
        #用城市選collection
        collection = db[db_collection]
        
        #第一階段篩選-用日期
        result1=collection.find({"Checkin_day":date_choose})
        print(result1)
        
#         #第二階段篩選-用停車
#         result2=result1.find({"Car_Park_State":car_p})
#         print("第二階段")
        
#         #第三階段篩選-用價錢區間
#         result3=result2.find(price_low<={"Price":Price}<=price_hight)
#         print("第三階段")
        
#         #第四階段篩選-用排序標準
#         if factor=="住宿地點":
#             result4=result3.find().sort({Location:-1});
#         elif factor=="清潔程度":
#             result4=result3.find().sort({Cleanliness:-1});
#         elif factor=="舒適程度":
#             result4=result3.find().sort({Comfort:-1});
#         print("第四階段")

#         content_num=len(result4)
#         for item in result4:
#             count=0
           
#             lb3.config(text=item["Name"])
#             lb4.config(text=item["Roomtype"])
#             lb5.config(text=item["Price"])


        #名稱資訊
        hotel_name_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text=item["Name"])

        #地址
        hotel_address_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text=city +item["District"])
        address_info.config(bg="#FFFFFF",fg="#FF0000", font=('微軟正黑體',13),text="詳細地址請點Google Map ->")
        #Google Map位置
        google_map.config(image=img,bg="#E8EEFF",width=64)
        google_map.place(x=1160,y=195)

        #入住日期
        check_date_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text=item[Checkin_day])

        #房型資訊
        roomtype_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text=item["Roomtype"])

        #停車資訊
        car_park_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text="宿場所設有私人停車設施（（免費））")

        #價錢
        price_info.config(bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),text=str(item["Price"])+" 元")
        #訂房網連結
        price_i.config(bg="#FFFFFF",fg="#FF0000", font=('微軟正黑體',13),text="訂房網連結 ->")

        #booking連結位置
        booking_link.config(image=img3,bg="#E8EEFF",width=64,)
        booking_link.place(x=980,y=465)
    
    return Link,Map_link

    

# 主視窗
win=tk.Tk()
#視窗屬性設定
win.title('菈蠂芮')
win.geometry('1350x700')
win.iconbitmap('luxury.ico')
win.config(bg="#E8E8E8")
win.attributes('-alpha',1)
# win.attributes('-topmost',True) #把畫面放在最前面，可以選擇不要
win.maxsize

#添加背景

canvas= Canvas(width=1350, height=700, highlightthickness=0, borderwidth=0)
canvas.place(x=0, y=0)
bg = PhotoImage(file='COVER2.png')
bgid = canvas.create_image(0, 0, image=bg, anchor='nw')

reslut_bg =canvas.create_rectangle(650,195,1280,645,fill="#E8EEFF",width = 0)


#標示
title=tk.Label(text='請設定需求條件，將為您提供高CP值飯店 ^^')
title.config(bg="#E8F1FF",fg="#000000", font=('微軟正黑體',13))
title.place(x=100,y=45)

#建立日曆
cal = Calendar(win, selectmode = 'day',cursor="hand1",
               year = 2022, month = 6,
               day = 0)
cal.config(selectbackground="#FFC8B4",selectforeground="#000000")
cal.place(x=80,y=95)

#確認按鈕
Button(win, text = "click",bg="#FFFFFF",fg="#1C1C1C", font=('微軟正黑體',13),
       command = grad_date).place(x=310,y=215)

#顯示已選擇的日期
day_t=tk.Label(text="已選擇的日期")
day_t.config(bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',12))
day_t.place(x=420,y=152)
day=tk.Label(text=" ")
day.config(bg="#E8F8FF",fg="#FF0000", font=('微軟正黑體',12))
day.place(x=420,y=180)


#篩選條件:城市
place_t=tk.Label(text="選擇居住地區")
place_t.config(bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',12))#FFF8EC
place_t.place(x=130,y=330)
place = ["地區",
         "台北市",
         "新北市",
         "桃園市",
         "台中市",
         "台南市",
         "高雄市"]                      
place_r = ttk.Combobox(win, width=8,state="readonly", font=('微軟正黑體',13))
place_r["values"] = place
place_r.place(x=135,y=360)
place_r.current(0)
combostyle = ttk.Style()
#設定下拉選單顏色
combostyle.theme_create('combostyle', parent='alt',
settings={'TCombobox':
{'configure':
{
'foreground': '#000000', # 字顏色
'selectforeground': '#FF0000', # 被選擇的字顏色
'selectbackground': '#FFFFFF', # 被選擇的背景顏色
'fieldbackground': '#FFFFFF', # 下拉框颜色
'background': '#E8F8FF', # 下拉按钮颜色

}}}
)
combostyle.theme_use('combostyle')


#篩選條件:人數
people= ["住宿人數",
         "2人",
         "4人"]                      
people_r = ttk.Combobox(win, width=8, state="readonly", font=('微軟正黑體',13))
people_r["values"] =people
people_r.place(x=135,y=415)
people_r.current(0)


#篩選條件:考量因素
rates_t=tk.Label(text="優先考量因素")
rates_t.config(bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',12))
rates_t.place(x=130,y=465)
rates= ["選項",
         "住宿地點",
         "清潔程度",
         "舒適程度"]                      
rates_r = ttk.Combobox(win, width=8, state="readonly", font=('微軟正黑體',13))
rates_r["values"] =rates
rates_r.place(x=135,y=500)
rates_r.current(0)

#篩選條件:停車需求
park=tk.Label(win, text="停車需求", bg="#E8F8FF",fg="#1C1C1C",width=6, font=('微軟正黑體',13)).place(x=330,y=470)
v= tk.IntVar()
tk.Radiobutton(win, text="需要",variable=v, value=1,bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',13)).place(x=320,y=495)
tk.Radiobutton(win, text="不用",variable=v, value=2,bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',13)).place(x=390,y=495)


#篩選條件:價格
dollar=tk.Label(text='預算範圍')
dollar.config(bg="#E8F8FF",fg="#1C1C1C", font=('微軟正黑體',13))
dollar.place(x=130,y=550)

#篩選條件:價格範圍-低
dollar_low=tk.Entry()
dollar_low.delete(0,"end")
dollar_low.config(width=6)
dollar_low.place(x=135,y=580)

#to
to=tk.Label(text="元 ~")
to.config(fg="#000000",bg="#E8F8FF", font=('微軟正黑體',13),width=3)
to.place(x=190,y=575)

#篩選條件:價格範圍-高
dollar_hight=tk.Entry()
dollar_hight.delete(0,"end")
dollar_hight.config(width=6)
dollar_hight.place(x=230,y=580)
#元
to=tk.Label(text="元")
to.config(fg="#000000",bg="#E8F8FF", font=('微軟正黑體',13),width=3)
to.place(x=275,y=575)


#查詢
btn=tk.Button(text='查詢')
img2=tk.PhotoImage(file="Icon_button.png") 
btn.config(image=img2,bg="#E8EEFF",width=64,command=choose)
btn.place(x=470,y=550)
# date_choose,city,db_collection,db_name,people_num,factor,car_p,price_low,price_hight=choose()
# c_title(date_choose,city,db_collection,db_name,people_num,factor,car_p,price_low,price_hight)

#-----------輸出-----------------------------------------------------------------


#結果標示
title=tk.Label(text='推薦飯店資訊')
title.config(bg="#FFFFFF",fg="#000000", font=('微軟正黑體',13))
title.place(x=745,y=42)

#名稱資訊
hotel_name_info=tk.Label()
hotel_name_info.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',13),text="")
hotel_name_info.place(x=760,y=140)

#地址資訊
hotel_address_info=tk.Label()
hotel_address_info.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',13),text="")
hotel_address_info.place(x=760,y=210)
#詳細地址
address_info=tk.Label()
address_info.config(bg="#E8EEFF",fg="#FF0000", font=('微軟正黑體',13),text="")
address_info.place(x=900,y=210)
#Google Map
img=tk.PhotoImage(file="Google_Maps_logo.png")
google_map = tk.Button()
google_map.config(image=img,bg="#E8EEFF",width=64)
google_map.place(x=1200,y=120)


#入住日期
check_date_info=tk.Label()
check_date_info.config(bg="#E8EEFF",fg="#FF0000", font=('微軟正黑體',13),text="")
check_date_info.place(x=760,y=277)

#房型資訊
roomtype_info=tk.Label()
roomtype_info.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',13),text="")
roomtype_info.place(x=760,y=345)

#停車資訊
car_park_info=tk.Label()
car_park_info.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',13),text="")
car_park_info.place(x=760,y=410)

#價錢資訊
price_info=tk.Label()
price_info.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',13),text="")
price_info.place(x=760,y=475)

#訂房網連結
price_i=tk.Label()
price_i.config(bg="#E8EEFF",fg="#FF0000", font=('微軟正黑體',13),text="")
price_i.place(x=840,y=475)

#booking連結
img3=tk.PhotoImage(file="booking-logo.png")
booking_link = tk.Button()
booking_link.config(image=img3,bg="#E8EEFF",width=64)
booking_link.place(x=1100,y=120)



#搜尋公告:
lb1=tk.Label()
lb1.config(bg="#FFFFFF",fg="#1C1C1C",font=('微軟正黑體',13),text="設定好條件，我將為您服務 ^ ^")
lb1.place(x=760,y=140)

#更新時間公告:
lb2=tk.Label(text="最終更新: 2022-05-22")
lb2.config(bg="#E8EEFF",fg="#1C1C1C", font=('微軟正黑體',12))
lb2.place(x=1110,y=600)



win.mainloop()
