# %%
import pymongo
import pandas as pd

client=pymongo.MongoClient("mongodb+srv://帳號:密碼@mongodb連線通道")
db=client.資料庫名稱
collection=db.資料表名稱

result=collection.find({"Car_Park_State":"Yes"})

for price in result:
    print (price["Car_Park"])
# Out:
# 宿附近提供公共停車設施（每 日 TWD 100）
# 提供停車相關設施
# 宿場所設有私人停車設施（（免費））
# 宿場所設有私人停車設施（（免費））
# 提供停車相關設施
# 宿附近設有私人停車設施（（免費））
# 宿附近設有私人停車設施（（免費））
# 宿場所設有公共停車設施（（免費））
# 宿場所設有私人停車設施（（免費））
# 提供停車相關設施
# 提供停車相關設施
# 宿附近提供私人停車設施（每 日 TWD 150）
# 宿附近提供公共停車設施（每 日 TWD 200）
# 宿場所設有私人停車設施（（免費））
# 宿場所設有私人停車設施（（免費））
# 宿附近設有私人停車設施（（免費））
# 宿場所設有私人停車設施（（免費））
# 宿附近設有私人停車設施（（免費））
# 宿附近提供公共停車設施（（收費））
# 宿場所設有私人停車設施（（免費））
# 宿附近提供私人停車設施（每 日 TWD 200）
# 宿附近提供公共停車設施（每 小時 TWD 30）
# 宿附近設有私人停車設施（（免費））
# 提供停車相關設施
# 宿場所設有私人停車設施（（免費））
# 宿附近提供私人停車設施（每 次住宿 TWD 200）
# 宿附近設有公共停車設施（（免費））
# 宿附近設有公共停車設施（（免費））
# 宿場所設有私人停車設施（（免費））
# 提供停車相關設施
# 宿場所設有公共停車設施（（免費））
# 宿附近設有公共停車設施（（免費））
# 住宿方于全館提供WiFi（免費）。
# 宿場所設有私人停車設施（（免費））
# 宿附近提供私人停車設施（每 日 TWD 200）
# 提供停車相關設施
# 提供停車相關設施
# 宿場所提供私人停車設施（，有可能收取費用）
# 提供停車相關設施
# 宿附近提供公共停車設施（每 日 TWD 500）
# 住宿方于全館提供WiFi（免費）。
# 宿附近設有私人停車設施（（免費））
# 宿附近提供公共停車設施（每 小時 TWD 40）
# 宿附近設有公共停車設施（（免費））
# 宿附近提供公共停車設施（，有可能收取費用）
# 宿附近提供公共停車設施（每 日 TWD 100）
# 宿附近提供私人停車設施（每 日 TWD 100）
# 宿場所設有公共停車設施（（免費））
# 住宿方不提供互聯網連接。
# ...
